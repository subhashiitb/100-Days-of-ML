# %% [markdown]
# <a href="https://colab.research.google.com/github/subhashiitb/100-Days-of-ML/blob/main/DL-Project/Image-1/image-process-dl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget 'https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg'
# Out:
# --2026-09-04 03:15:08--  https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg
# Resolving tractive.com (tractive.com)... 13.227.87.51, 13.227.87.80, 13.227.87.77, ...
# Connecting to tractive.com (tractive.com)|13.227.87.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113570 (111K) [image/jpeg]
# Saving to: ‘puppy-care-guide-for-new-parents.jpg’
#
# puppy-care-guide-fo 100%[===================>] 110.91K   584KB/s    in 0.2s
#
# 2026-09-04 03:15:09 (584 KB/s) - ‘puppy-care-guide-for-new-parents.jpg’ saved [113570/113570]

# %%
 #importing the image module from matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/content/puppy-care-guide-for-new-parents.jpg')
