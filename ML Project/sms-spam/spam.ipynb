# %% [markdown]
# <a href="https://colab.research.google.com/github/subhashiitb/100-Days-of-ML/blob/main/ML%20Project/sms-spam/spam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
# Download latest version
path = kagglehub.dataset_download("uciml/sms-spam-collection-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'sms-spam-collection-dataset' dataset.
# Path to dataset files: /kaggle/input/sms-spam-collection-dataset

# %%
import pandas as pd

# Configure pandas display options for better formatting
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# Read the CSV file from the downloaded dataset
df = pd.read_csv(f"{path}/spam.csv", encoding='latin-1')

# Display the first few rows
print("Dataset shape:", df.shape)
print("\nFirst 5 rows:")
display(df.head())
# Out:
# Dataset shape: (5572, 5)
#
# First 5 rows:
#      v1  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                                                                             v2  \
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                            U dun say so early hor... U c already then say...
# ...

# %% [markdown]
# # **1. Data Cleaning**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
# drop last 3 columns
df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace=True)

# %%
df.sample(2)
# Out:
#        v1  \
# 1552  ham
# 3160  ham
#
#                                                                                            v2
# 1552                                                                                 U too...
# 3160  Mystery solved! Just opened my email and he's sent me another batch! Isn't he a sweetie

# %%
# Rename the columns
df.rename(columns={'v1': 'target', 'v2': 'text'}, inplace=True)
df.sample(2)
# Out:
#      target  \
# 1595    ham
# 3921    ham
#
#                                                                                 text
# 1595                                     Pls confirm the time to collect the cheque.
# 3921  Oh really? perform, write a paper, go to a movie AND be home by midnight, huh?

# %%
# Label Encoder
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target  \
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#
#                                                                                                                                                           text
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                            U dun say so early hor... U c already then say...
# ...

# %%
# Missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# Duplicate
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
# Remove duplicates
df.drop_duplicates(keep='first', inplace=True)

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# # **2. EDA**

# %%
df.head( )
# Out:
#    target  \
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#
#                                                                                                                                                           text
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                            U dun say so early hor... U c already then say...
# ...

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(), labels=['ham', 'spam'], autopct='%1.1f%%')
plt.show()

# %%
# Data is Imbalanced

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df['num_char'] = df['text'].apply(len)
df.sample()
# Out:
#       target                      text  num_char
# 2037       0  Oh sorry please its over        24

# %%
nltk.download('punkt_tab', quiet=True)
# number of words
df['num_words'] = df['text'].apply(lambda x:len(nltk.word_tokenize(x)))
df.head(2)
# Out:
#    target  \
# 0       0
# 1       0
#
#                                                                                                               text  \
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                    Ok lar... Joking wif u oni...
#
#    num_char  num_words
# 0       111         24
# 1        29          8

# %%
# Number of sentences
df['num_sentences'] = df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))
df.head(2)
# Out:
#    target  \
# 0       0
# 1       0
#
#                                                                                                               text  \
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                    Ok lar... Joking wif u oni...
#
#    num_char  num_words  num_sentences
# 0       111         24              2
# 1        29          8              2

# %%
df[['num_char','num_words','num_sentences']].describe()
# Out:
#           num_char    num_words  num_sentences
# count  5169.000000  5169.000000    5169.000000
# mean     78.977945    18.455794       1.965564
# std      58.236293    13.324758       1.448541
# min       2.000000     1.000000       1.000000
# 25%      36.000000     9.000000       1.000000
# 50%      60.000000    15.000000       1.000000
# 75%     117.000000    26.000000       2.000000
# max     910.000000   220.000000      38.000000

# %%
df[df['target'] == 0][['num_char','num_words','num_sentences']].describe()
# Out:
#           num_char    num_words  num_sentences
# count  4516.000000  4516.000000    4516.000000
# mean     70.459256    17.123782       1.820195
# std      56.358207    13.493970       1.383657
# min       2.000000     1.000000       1.000000
# 25%      34.000000     8.000000       1.000000
# 50%      52.000000    13.000000       1.000000
# 75%      90.000000    22.000000       2.000000
# max     910.000000   220.000000      38.000000

# %%
df[df['target'] == 1][['num_char','num_words','num_sentences']].describe()
# Out:
#          num_char   num_words  num_sentences
# count  653.000000  653.000000     653.000000
# mean   137.891271   27.667688       2.970904
# std     30.137753    7.008418       1.488425
# min     13.000000    2.000000       1.000000
# 25%    132.000000   25.000000       2.000000
# 50%    149.000000   29.000000       3.000000
# 75%    157.000000   32.000000       4.000000
# max    224.000000   46.000000       9.000000

# %%
# Histogram PLot

import seaborn as sns
plt.figure(figsize=(12, 6))
sns.histplot(df[df['target'] == 0]['num_char'])
sns.histplot(df[df['target'] == 1]['num_char'])
#
# Out:
# <Axes: xlabel='num_char', ylabel='Count'>

# %%
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'])
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
# Co-relation coefficients

# %%
sns.pairplot(df, hue='target')

# %%
sns.heatmap(df[['target','num_char','num_words','num_sentences']].corr(), annot=True)
# Out:
# <Axes: >

# %%
# Multi co linearity exists therefore need Data pre processing

# %% [markdown]
# # **3. Data Preprocessing**

# %%
import string
from nltk.classify import textcat
from nltk.corpus import stopwords
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)

    y = []
    for i in text:
      if i.isalnum():
        y.append(i)

    text = y[:]
    y.clear()

    for i in text:
      if i not in stopwords.words('english') and i not in string.punctuation:
        y.append(i)

    return y

# %%
import nltk
nltk.download('stopwords')
transform_text("Hello % how ??")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['hello']

# %%
df['text'][0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
transform_text(df['text'][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_919/3934176354.py in <cell line: 0>()
# ----> 1 transform_text(df['text'][0])
#
# /tmp/ipykernel_919/3431414941.py in transform_text(text)
#      14
#      15     for i in text:
# ---> 16       if i not in stopwords.words('english') and i not in string.punctuation:
#      17         y.append(i)
#      18
#
# NameError: name 'stopwords' is not defined

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

# %%
stopwords.words('english')

# %%
transform_text("Hi, How are you Subhash")

# %%
df['text'][2000]

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('dancing')
